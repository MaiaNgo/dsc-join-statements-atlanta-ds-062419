# %% [markdown]
# # Join Statements

# %% [markdown]
# ## Introduction
#
# In this section, you will learn about several types of join statements.  Joins are the primary mechanism for combining data from multiple tables. In order to do this, you define the common attribute(s) between tables in order for them to be combined.
#
# ## Objectives
#
# You will be able to:
#
# * Compare and contrast the various types of joins
# * Discuss the syntax and structure of join statements
# * Discuss the role of foreign and primary keys in them
#
# ## CRM Schema
#
# In almost all industry cases, rather than just working with a single table you will generally need data from multiple tables. Doing this requires the use of **joins** using shared columns from the two tables. For example, here's a diagram of a mock customer relationship management database.
# <img src='images/Database-Schema.png' width=550>

# %% [markdown]
# ## Connecting to the Database
#
# As usual, you'll start by connecting to the database.

# %%
import sqlite3
import pandas as pd

# %%
conn = sqlite3.connect('data.sqlite', detect_types=sqlite3.PARSE_COLNAMES)
cur = conn.cursor()

# %% [markdown]
# ## Displaying product details along with order details
# Let's say you need to generate some report that includes details about products from orders. To do that, we would need to take data from multiple tables in a single statement.

# %%
cur.execute("""select * 
               from orderdetails join products
               on orderdetails.productCode = products.productCode
               limit 50;
            """)
df = pd.DataFrame(cur.fetchall()) #Take results and create dataframe
df.columns = [i[0] for i in cur.description]
df.head(50)
# Out:
#    orderNumber productCode quantityOrdered priceEach orderLineNumber  \
# 0        10100    S18_1749              30    136.00               3
# 1        10100    S18_2248              50     55.09               2
# 2        10100    S18_4409              22     75.46               4
# 3        10100    S24_3969              49     35.29               1
# 4        10101    S18_2325              25    108.06               4
# 5        10101    S18_2795              26    167.06               1
# 6        10101    S24_1937              45     32.53               3
# 7        10101    S24_2022              46     44.35               2
# 8        10102    S18_1342              39     95.55               2
# 9        10102    S18_1367              41     43.13               1
# 10       10103    S10_1949              26    214.30              11
# 11       10103    S10_4962              42    119.67               4
# 12       10103    S12_1666              27    121.64               8
# 13       10103    S18_1097              35     94.50              10
# 14       10103    S18_2432              22     58.34               2
# 15       10103    S18_2949              27     92.19              12
# 16       10103    S18_2957              35     61.84              14
# 17       10103    S18_3136              25     86.92              13
# 18       10103    S18_3320              46     86.31              16
# 19       10103    S18_4600              36     98.07               5
# 20       10103    S18_4668              41     40.75               9
# 21       10103    S24_2300              36    107.34               1
# 22       10103    S24_4258              25     88.62              15
# 23       10103    S32_1268              31     92.46               3
# 24       10103    S32_3522              45     63.35               7
# 25       10103   S700_2824              42     94.07               6
# 26       10104    S12_3148              34    131.44               1
# 27       10104    S12_4473              41    111.39               9
# 28       10104    S18_2238              24    135.90               8
# 29       10104    S18_2319              29    122.73              12
# 30       10104    S18_3232              23    165.95              13
# 31       10104    S18_4027              38    119.20               3
# 32       10104    S24_1444              35     52.02               6
# 33       10104    S24_2840              44     30.41              10
# 34       10104    S24_4048              26    106.45               5
# 35       10104    S32_2509              35     51.95              11
# 36       10104    S32_3207              49     56.55               4
# 37       10104    S50_1392              33    114.59               7
# 38       10104    S50_1514              32     53.31               2
# 39       10105    S10_4757              50    127.84               2
# 40       10105    S12_1108              41    205.72              15
# 41       10105    S12_3891              29    141.88              14
# 42       10105    S18_3140              22    136.59              11
# 43       10105    S18_3259              38     87.73              13
# 44       10105    S18_4522              41     75.48              10
# 45       10105    S24_2011              43    117.97               9
# 46       10105    S24_3151              44     73.46               4
# 47       10105    S24_3816              50     75.47               1
# 48       10105   S700_1138              41     54.00               5
# 49       10105   S700_1938              29     86.61              12
#
#    productCode                                  productName       productLine  \
# 0     S18_1749                     1917 Grand Touring Sedan      Vintage Cars
# 1     S18_2248                           1911 Ford Town Car      Vintage Cars
# 2     S18_4409          1932 Alfa Romeo 8C2300 Spider Sport      Vintage C
# 48   S700_1138                        The Schooner Bluenose             Ships
# 49   S700_1938                                The Mayflower             Ships
#
#    productScale              productVendor  \
# 0          1:18  Welly Diecast Productions
# 1          1:18    Motor City Art Classics
# 2          1:18              Exoto Designs
# 3          1:24          Red Start Diecast
# 4          1:18      Autoart Studio Design
# 5          1:18       Gearbox Collectibles
# 6          1:24    Motor City Art Classics
# 7          1:24    Classic Metal Creations
# 8          1:18    Motor City Art Classics
# 9          1:18        Studio M Art Models
# 10         1:10    Classic Metal Creations
# 11         1:10        Second Gear Diecast
# 12         1:12  Welly Diecast Productions
# 13         1:18        Studio M Art Models
# 14         1:18   Carousel DieCast Legends
# 15         1:18   Carousel DieCast Legends
# 16         1:18            Min Lin Diecast
# 17         1:18          Red Start Diecast
# 18         1:18              Exoto Designs
# 19         1:18    Motor City Art Classics
# 20         1:18        Studio M Art Models
# 21         1:24      Autoart Studio Design
# 22         1:24        Second Gear Diecast
# 23         1:32    Motor City Art Classics
# 24         1:32          Red Start Diecast
# 25         1:18   Carousel DieCast Legends
# 26         1:18  Welly Diecast Productions
# 27         1:12              Exoto Designs
# 28         1:18       Gearbox Collectibles
# 29         1:18       Unimax Art Galleries
# 30         1:18       Unimax Art Galleries
# 31         1:18            Min Lin Diecast
# 32         1:24   Highway 66 Mini Classics
# 33         1:24   Carousel DieCast Legends
# 34         1:24              Exoto Designs
# 35         1:32    Classic Metal Creations
# 36         1:32       Gearbox Collectibles
# 37         1:50   Highway 66 Mini Classics
# 38         1:50    Classic Metal Creations
# 39         1:10    Motor City Art Classics
# 40         1:12        Second Gear Diecast
# 41         1:12        Second Gear Diecast
# 42         1:18       Unimax Art Galleries
# 43         1:18   Carousel DieCast Legends
# 44         1:18              Exoto Designs
# 45         1:24   Carousel DieCast Legends
# 46         1:24            Min Lin Diecast
# 47         1:24   Carousel DieCast Legends
# 48        1:700      Autoart Studio Design
# 49        1:700        Studio M Art Models
#
#                                    productDescription quantityInStock  \
# 0   This 1:18 scale replica of the 1917 Grand Tour...            2724
# 1   Features opening hood, opening doors, opening ...             540
# 2   This 1:18 scale precision die cast replica fea...            6553
# 3   This model features grille-mounted chrome horn...            2081
# 4   This model features grille-mounted chrome horn...            9354
# 5   This 1:18 replica features grille-mounted chro...             548
# 6   This 1:24 scale die-cast replica of the 1939 C...            7332
# 7   This 1:24 scale precision die cast replica of ...            2847
# 8   Features opening engine cover, doors, trunk, a...            8693
# 9   This 1:18 scale replica is constructed of heav...            8635
# 10  Turnable front wheels; steering function; deta...            7305
# 11  Features include: Turnable front wheels; steer...            6791
# 12  Model features 30 windows, skylights & glare r...            1579
# 13  This model features soft rubber tires, working...            2613
# 14  Gleaming red handsome appearance. Everything i...            2018
# 15  This 250 part reproduction includes moving han...            4189
# 16  Chrome Trim, Chrome Grille, Opening Hood, Open...            5649
# 17  Hand crafted diecast-like metal horse carriage...            5992
# 18  Features Gold Trim, Full Size Spare Tire, Chro...            7913
# 19  This 1940s Ford Pick-Up truck is re-created in...            3128
# 20  Features completely detailed interior includin...            6645
# 21  This 1:18 scale die cast replica of the 1962 M...            2327
# 22  Features opening trunk,  working steering syst...            4710
# 23  This 1980’s era new look Manhattan express is ...            5099
# 24  This model features, opening doors, detailed e...             814
# 25  Features include opening and closing doors. Co...            6934
# 26  1:18 scale die-cast about 10" long doors open,...            6906
# 27  1:12 scale die-cast about 20" long Hood opens,...            6125
# 28  Turnable front wheels; steering function; deta...            4724
# 29  Exact replica. 100+ parts. working steering sy...            8258
# 30  his replica features opening doors, superb det...            8347
# 31  Features include opening and closing doors. Co...            5545
# 32  1:24 scale die-cast about 18" long doors open,...            4074
# 33  The operating parts of this 1958 Chevy Corvett...            2542
# 34  This replica features opening doors, superb de...            6582
# 35  Model features bi-level seating, 50 windows, s...            2874
# 36  This streetcar is a joy to see. It has 80 sepa...            8601
# 37  This limited edition model is licensed and per...            1016
# 38  This streetcar is a joy to see. It has 99 sepa...            1645
# 39  Features include: Turnable front wheels; steer...            3252
# 40  Turnable front wheels; steering function; deta...            3619
# 41  Turnable front wheels; steering function; deta...            1049
# 42   Features opening trunk,  working steering system            3913
# 43  Hand crafted wooden toy train set is in about ...            6450
# 44   Features opening trunk,  working steering system            8290
# 45  All wood with canvas sails. Many extras includ...            1898
# 46  This model features chrome trim and grille, op...            9173
# 47  Chrome Trim, Chrome Grille, Opening Hood, Open...            6621
# 48  All wood with canvas sails. Measures 31 1/2 in...            1897
# 49  Measures 31 1/2 inches Long x 25 1/2 inches Hi...             737
#
#    buyPrice    MSRP
# 0     86.70  170.00
# 1     33.30   60.54
# 2     43.26   92.03
# 3     21.75   41.03
# 4     58.48  127.13
# 5     72.56  168.75
# 6     22.57   33.19
# 7     20.61   44.80
# 8     60.62  102.74
# 9     24.26   53.91
# 10    98.58  214.30
# 11   103.42  147.74
# 12    77.90  136.67
# 13    58.33  116.67
# 14    24.92   60.77
# 15    60.78  101.31
# 16    34.35   62.46
# 17    60.74  104.72
# 18    57.54   99.21
# 19    84.76  121.08
# 20    23.14   50.31
# 21    61.34  127.79
# 22    57.46   97.39
# 23    53.93   96.31
# 24    33.61   64.64
# 25    46.53  101.15
# 26    89.14  151.08
# 27    55.70  118.50
# 28   101.51  163.73
# 29    74.86  122.73
# 30    77.90  169.34
# 31    91.92  143.62
# 32    32.37   57.80
# 33    15.91   35.36
# 34    69.78  118.28
# 35    25.98   54.11
# 36    26.72   62.14
# 37    68.29  115.75
# 38    37.49   58.58
# 39    85.68  136.00
# 40    95.59  207.80
# 41    83.05  173.02
# 42    68.30  136.59
# 43    67.56  100.84
# 44    52.66   87.77
# 45    82.34  122.89
# 46    46.91   88.51
# 47    48.64   83.86
# 48    34.00   66.67
# 49    43.30   86.61

# %% [markdown]
# ## Compared to the individual tables:

# %% [markdown]
# ### orderdetails

# %%
cur.execute("""select * from orderdetails limit 50;""")
df = pd.DataFrame(cur.fetchall()) #Take results and create dataframe
df.columns = [i[0] for i in cur.description]
df.head(50)
# Out:
#    orderNumber productCode quantityOrdered priceEach orderLineNumber
# 0        10100    S18_1749              30    136.00               3
# 1        10100    S18_2248              50     55.09               2
# 2        10100    S18_4409              22     75.46               4
# 3        10100    S24_3969              49     35.29               1
# 4        10101    S18_2325              25    108.06               4
# 5        10101    S18_2795              26    167.06               1
# 6        10101    S24_1937              45     32.53               3
# 7        10101    S24_2022              46     44.35               2
# 8        10102    S18_1342              39     95.55               2
# 9        10102    S18_1367              41     43.13               1
# 10       10103    S10_1949              26    214.30              11
# 11       10103    S10_4962              42    119.67               4
# 12       10103    S12_1666              27    121.64               8
# 13       10103    S18_1097              35     94.50              10
# 14       10103    S18_2432              22     58.34               2
# 15       10103    S18_2949              27     92.19              12
# 16       10103    S18_2957              35     61.84              14
# 17       10103    S18_3136              25     86.92              13
# 18       10103    S18_3320              46     86.31              16
# 19       10103    S18_4600              36     98.07               5
# 20       10103    S18_4668              41     40.75               9
# 21       10103    S24_2300              36    107.34               1
# 22       10103    S24_4258              25     88.62              15
# 23       10103    S32_1268              31     92.46               3
# 24       10103    S32_3522              45     63.35               7
# 25       10103   S700_2824              42     94.07               6
# 26       10104    S12_3148              34    131.44               1
# 27       10104    S12_4473              41    111.39               9
# 28       10104    S18_2238              24    135.90               8
# 29       10104    S18_2319              29    122.73              12
# 30       10104    S18_3232              23    165.95              13
# 31       10104    S18_4027              38    119.20               3
# 32       10104    S24_1444              35     52.02               6
# 33       10104    S24_2840              44     30.41              10
# 34       10104    S24_4048              26    106.45               5
# 35       10104    S32_2509              35     51.95              11
# 36       10104    S32_3207              49     56.55               4
# 37       10104    S50_1392              33    114.59               7
# 38       10104    S50_1514              32     53.31               2
# 39       10105    S10_4757              50    127.84               2
# 40       10105    S12_1108              41    205.72              15
# 41       10105    S12_3891              29    141.88              14
# 42       10105    S18_3140              22    136.59              11
# 43       10105    S18_3259              38     87.73              13
# 44       10105    S18_4522              41     75.48              10
# 45       10105    S24_2011              43    117.97               9
# 46       10105    S24_3151              44     73.46               4
# 47       10105    S24_3816              50     75.47               1
# 48       10105   S700_1138              41     54.00               5
# 49       10105   S700_1938              29     86.61              12

# %% [markdown]
# ### products

# %%
cur.execute("""select * from products limit 50;""")
df = pd.DataFrame(cur.fetchall()) #Take results and create dataframe
df.columns = [i[0] for i in cur.description]
df.head(50)
# Out:
#    productCode                               productName       productLine  \
# 0     S10_1678     1969 Harley Davidson Ultimate Chopper       Motorcycles
# 1     S10_1949                  1952 Alpine Renault 1300      Classic Cars
# 2     S10_2016                     1996 Moto Guzzi 1100i       Motorcycles
# 3     S10_4698      2003 Harley-Davidson Eagle Drag Bike       Motorcycles
# 4     S10_4757                       1972 Alfa Romeo GTA      Classic Cars
# 5     S10_4962                    1962 LanciaA Delta 16V      Classic Cars
# 6     S12_1099                         1968 Ford Mustang      Classic Cars
# 7     S12_1108                         2001 Ferrari Enzo      Classic Cars
# 8     S12_1666                            1958 Setra Bus  Trucks and Buses
# 9     S12_2823                          2002 Suzuki XREO       Motorcycles
# 10    S12_3148                        1969 Corvair Monza      Classic Cars
# 13         1:12        Studio M Art Models
# 14         1:12              Exoto Designs
# 15         1:12  Welly Diecast Productions
# 16         1:18        Studio M Art Models
# 17         1:18   Highway 66 Mini Classics
# 18         1:18    Motor City Art Classics
# 19         1:18        Studio M Art Models
# 20         1:18    Classic Metal Creations
# 21         1:18          Red Start Diecast
# 22         1:18  Welly Diecast Productions
# 23         1:18       Gearbox Collectibles
# 24         1:18            Min Lin Diecast
# 25         1:18       Gearbox Collectibles
# 26         1:18    Motor City Art Classics
# 27         1:18       Unimax Art Galleries
# 28         1:18      Autoart Studio Design
# 29         1:18   Carousel DieCast Legends
# 30         1:72       Gearbox Collectibles
# 31         1:18  Welly Diecast Productions
# 32         1:18       Gearbox Collectibles
# 33         1:18          Red Start Diecast
# 34         1:18   Carousel DieCast Legends
# 35         1:18            Min Lin Diecast
# 36         1:18            Min Lin Diecast
# 37         1:18          Red Start Diecast
# 38         1:18       Unimax Art Galleries
# 39         1:18       Unimax Art Galleries
# 40         1:18   Highway 66 Mini Classics
# 41         1:18   Carousel DieCast Legends
# 42         1:18            Min Lin Diecast
# 43         1:18              Exoto Designs
# 44         1:18       Gearbox Collectibles
# 45         1:18       Gearbox Collectibles
# 46         1:18        Studio M Art Models
# 47         1:18              Exoto Designs
# 48         1:18            Min Lin Diecast
# 49         1:18              Exoto Designs
#
#                                    productDescription quantityInStock  \
# 0   This replica features working kickstand, front...            7933
# 1   Turnable front wheels; steering function; deta...            7305
# 2   Official Moto Guzzi logos and insignias, saddl...            6625
# 3   Model features, official Harley Davidson logos...            5582
# 4   Features include: Turnable front wheels; steer...            3252
# 5   Features include: Turnable front wheels; steer...            6791
# 6   Hood, doors and trunk all open to reveal highl...              68
# 7   Turnable front wheels; steering function; deta...            3619
# 8   Model features 30 windows, skylights & glare r...            1579
# 9   Official logos and insignias, saddle bags loca...            9997
# 10  1:18 scale die-cast about 10" long doors open,...            6906
# 11  1:12 scale model of a 1968 Dodge Charger. Hood...            9123
# 12  Turnable front wheels; steering function; deta...            1049
# 13  Very detailed 1970 Plymouth Cuda model in 1:12...            5663
# 14  1:12 scale die-cast about 20" long Hood opens,...            6125
# 15  Detailed model of the 1969 Dodge Charger. This...            7323
# 16  This model features soft rubber tires, working...            2613
# 17  This model features, opening hood, opening doo...            3975
# 18  Features opening engine cover, doors, trunk, a...            8693
# 19  This 1:18 scale replica is constructed of heav...            8635
# 20  Die-cast model of the silver 1965 Aston Martin...            9042
# 21  1:18 scale replica of actual Army's UH-60L BLA...            5330
# 22  This 1:18 scale replica of the 1917 Grand Tour...            2724
# 23  This precision die-cast replica features openi...            8826
# 24  This model features, opening hood, opening doo...            9772
# 25  Turnable front wheels; steering function; deta...            4724
# 26  Features opening hood, opening doors, opening ...             540
# 27  Exact replica. 100+ parts. working steering sy...            8258
# 28  This model features grille-mounted chrome horn...            9354
# 29  Gleaming red handsome appearance. Everything i...            2018
# 30      Has retractable wheels and comes with a stand             992
# 31  Intricately detailed with chrome accents and t...            4357
# 32  This 1:18 replica features grille-mounted chro...             548
# 33  Features include opening and closing doors. Co...            8164
# 34  This 250 part reproduction includes moving han...            4189
# 35  Chrome Trim, Chrome Grille, Opening Hood, Open...            5649
# 36  Exact replica. Wood and Metal. Many extras inc...            4259
# 37  Hand crafted diecast-like metal horse carriage...            5992
# 38   Features opening trunk,  working steering system            3913
# 39  his replica features opening doors, superb det...            8347
# 40  This model features soft rubber tires, working...            7733
# 41  Hand crafted wooden toy train set is in about ...            6450
# 42  This replica features opening doors, superb de...            1917
# 43  Features Gold Trim, Full Size Spare Tire, Chro...            7913
# 44  Highly detailed 1976 Ford Gran Torino "Starsky...            9127
# 45  This model features working front and rear sus...            8990
# 46  Features rotating wheels , working kick stand....            7689
# 47  Features opening hood, opening doors, opening ...            2378
# 48  Features include opening and closing doors. Co...            5545
# 49  This 1:18 scale precision die cast replica fea...            6553
#
#    buyPrice    MSRP
# 0     48.81   95.70
# 1     98.58  214.30
# 2     68.99  118.94
# 3     91.02  193.66
# 4     85.68  136.00
# 5    103.42  147.74
# 6     95.34  194.57
# 7     95.59  207.80
# 8     77.90  136.67
# 9     66.27  150.62
# 10    89.14  151.08
# 11    75.16  117.44
# 12    83.05  173.02
# 13    31.92   79.80
# 14    55.70  118.50
# 15    58.73  115.16
# 16    58.33  116.67
# 17    83.51  141.54
# 18    60.62  102.74
# 19    24.26   53.91
# 20    65.96  124.44
# 21    77.27  157.69
# 22    86.70  170.00
# 23    53.90   77.00
# 24    93.89  142.25
# 25   101.51  163.73
# 26    33.30   60.54
# 27    74.86  122.73
# 28    58.48  127.13
# 29    24.92   60.77
# 30    49.00   84.48
# 31    24.23   60.57
# 32    72.56  168.75
# 33    56.76  132.00
# 34    60.78  101.31
# 35    34.35   62.46
# 36    51.61   86.02
# 37    60.74  104.72
# 38    68.30  136.59
# 39    77.90  169.34
# 40    57.01  107.57
# 41    67.56  100.84
# 42    49.05   80.41
# 43    57.54   99.21
# 44    73.49  146.99
# 45    62.16  141.28
# 46    32.95   62.17
# 47    64.58  105.87
# 48    91.92  143.62
# 49    43.26   92.03

# %% [markdown]
# ## the using clause
# A more concise way to join the tables if the column name is identical is the using clause. Rather then saying on `tableA.column = tableB.column` we can simply say `using(column)`. Again, this only works if the column is identically named for both tables.

# %%
cur.execute("""select * from orderdetails
                        join products
                        using(productCode)
                        limit 50;
                       """)
df = pd.DataFrame(cur.fetchall()) #Take results and create dataframe
df.columns = [i[0] for i in cur.description]
df.head(50)
# Out:
#    orderNumber productCode quantityOrdered priceEach orderLineNumber  \
# 0        10100    S18_1749              30    136.00               3
# 1        10100    S18_2248              50     55.09               2
# 2        10100    S18_4409              22     75.46               4
# 3        10100    S24_3969              49     35.29               1
# 4        10101    S18_2325              25    108.06               4
# 5        10101    S18_2795              26    167.06               1
# 6        10101    S24_1937              45     32.53               3
# 7        10101    S24_2022              46     44.35               2
# 8        10102    S18_1342              39     95.55               2
# 9        10102    S18_1367              41     43.13               1
# 10       10103    S10_1949              26    214.30              11
# 11       10103    S10_4962              42    119.67               4
# 12       10103    S12_1666              27    121.64               8
# 49        1:700        Studio M Art Models
#
#                                    productDescription quantityInStock  \
# 0   This 1:18 scale replica of the 1917 Grand Tour...            2724
# 1   Features opening hood, opening doors, opening ...             540
# 2   This 1:18 scale precision die cast replica fea...            6553
# 3   This model features grille-mounted chrome horn...            2081
# 4   This model features grille-mounted chrome horn...            9354
# 5   This 1:18 replica features grille-mounted chro...             548
# 6   This 1:24 scale die-cast replica of the 1939 C...            7332
# 7   This 1:24 scale precision die cast replica of ...            2847
# 8   Features opening engine cover, doors, trunk, a...            8693
# 9   This 1:18 scale replica is constructed of heav...            8635
# 10  Turnable front wheels; steering function; deta...            7305
# 11  Features include: Turnable front wheels; steer...            6791
# 12  Model features 30 windows, skylights & glare r...            1579
# 13  This model features soft rubber tires, working...            2613
# 14  Gleaming red handsome appearance. Everything i...            2018
# 15  This 250 part reproduction includes moving han...            4189
# 16  Chrome Trim, Chrome Grille, Opening Hood, Open...            5649
# 17  Hand crafted diecast-like metal horse carriage...            5992
# 18  Features Gold Trim, Full Size Spare Tire, Chro...            7913
# 19  This 1940s Ford Pick-Up truck is re-created in...            3128
# 20  Features completely detailed interior includin...            6645
# 21  This 1:18 scale die cast replica of the 1962 M...            2327
# 22  Features opening trunk,  working steering syst...            4710
# 23  This 1980’s era new look Manhattan express is ...            5099
# 24  This model features, opening doors, detailed e...             814
# 25  Features include opening and closing doors. Co...            6934
# 26  1:18 scale die-cast about 10" long doors open,...            6906
# 27  1:12 scale die-cast about 20" long Hood opens,...            6125
# 28  Turnable front wheels; steering function; deta...            4724
# 29  Exact replica. 100+ parts. working steering sy...            8258
# 30  his replica features opening doors, superb det...            8347
# 31  Features include opening and closing doors. Co...            5545
# 32  1:24 scale die-cast about 18" long doors open,...            4074
# 33  The operating parts of this 1958 Chevy Corvett...            2542
# 34  This replica features opening doors, superb de...            6582
# 35  Model features bi-level seating, 50 windows, s...            2874
# 36  This streetcar is a joy to see. It has 80 sepa...            8601
# 37  This limited edition model is licensed and per...            1016
# 38  This streetcar is a joy to see. It has 99 sepa...            1645
# 39  Features include: Turnable front wheels; steer...            3252
# 40  Turnable front wheels; steering function; deta...            3619
# 41  Turnable front wheels; steering function; deta...            1049
# 42   Features opening trunk,  working steering system            3913
# 43  Hand crafted wooden toy train set is in about ...            6450
# 44   Features opening trunk,  working steering system            8290
# 45  All wood with canvas sails. Many extras includ...            1898
# 46  This model features chrome trim and grille, op...            9173
# 47  Chrome Trim, Chrome Grille, Opening Hood, Open...            6621
# 48  All wood with canvas sails. Measures 31 1/2 in...            1897
# 49  Measures 31 1/2 inches Long x 25 1/2 inches Hi...             737
#
#    buyPrice    MSRP
# 0     86.70  170.00
# 1     33.30   60.54
# 2     43.26   92.03
# 3     21.75   41.03
# 4     58.48  127.13
# 5     72.56  168.75
# 6     22.57   33.19
# 7     20.61   44.80
# 8     60.62  102.74
# 9     24.26   53.91
# 10    98.58  214.30
# 11   103.42  147.74
# 12    77.90  136.67
# 13    58.33  116.67
# 14    24.92   60.77
# 15    60.78  101.31
# 16    34.35   62.46
# 17    60.74  104.72
# 18    57.54   99.21
# 19    84.76  121.08
# 20    23.14   50.31
# 21    61.34  127.79
# 22    57.46   97.39
# 23    53.93   96.31
# 24    33.61   64.64
# 25    46.53  101.15
# 26    89.14  151.08
# 27    55.70  118.50
# 28   101.51  163.73
# 29    74.86  122.73
# 30    77.90  169.34
# 31    91.92  143.62
# 32    32.37   57.80
# 33    15.91   35.36
# 34    69.78  118.28
# 35    25.98   54.11
# 36    26.72   62.14
# 37    68.29  115.75
# 38    37.49   58.58
# 39    85.68  136.00
# 40    95.59  207.80
# 41    83.05  173.02
# 42    68.30  136.59
# 43    67.56  100.84
# 44    52.66   87.77
# 45    82.34  122.89
# 46    46.91   88.51
# 47    48.64   83.86
# 48    34.00   66.67
# 49    43.30   86.61

# %% [markdown]
# ## Aliasing
# Alternatively, you can also alias tables by giving them an alternative shorthand name directly after them. Here we use the aliases 'o' and 'p' for orderdetails and products respectively.

# %%
cur.execute("""select * from orderdetails o
                        join products p
                        on o.productCode = p.productCode
                        limit 10;
                       """)
df = pd.DataFrame(cur.fetchall()) #Take results and create dataframe
df.columns = [i[0] for i in cur.description]
df.head()
# Out:
#   orderNumber productCode quantityOrdered priceEach orderLineNumber  \
# 0       10100    S18_1749              30    136.00               3
# 1       10100    S18_2248              50     55.09               2
# 2       10100    S18_4409              22     75.46               4
# 3       10100    S24_3969              49     35.29               1
# 4       10101    S18_2325              25    108.06               4
#
#   productCode                          productName   productLine productScale  \
# 0    S18_1749             1917 Grand Touring Sedan  Vintage Cars         1:18
# 1    S18_2248                   1911 Ford Town Car  Vintage Cars         1:18
# 2    S18_4409  1932 Alfa Romeo 8C2300 Spider Sport  Vintage Cars         1:18
# 3    S24_3969     1936 Mercedes Benz 500k Roadster  Vintage Cars         1:24
# 4    S18_2325            1932 Model A Ford J-Coupe  Vintage Cars         1:18
#
#                productVendor  \
# 0  Welly Diecast Productions
# 1    Motor City Art Classics
# 2              Exoto Designs
# 3          Red Start Diecast
# 4      Autoart Studio Design
#
#                                   productDescription quantityInStock buyPrice  \
# 0  This 1:18 scale replica of the 1917 Grand Tour...            2724    86.70
# 1  Features opening hood, opening doors, opening ...             540    33.30
# 2  This 1:18 scale precision die cast replica fea...            6553    43.26
# 3  This model features grille-mounted chrome horn...            2081    21.75
# 4  This model features grille-mounted chrome horn...            9354    58.48
#
#      MSRP
# 0  170.00
# 1   60.54
# 2   92.03
# 3   41.03
# 4  127.13

# %% [markdown]
# ## Left Joins
#
# By default, a join is an inner join, or the intersection between two tables. In other words, the join between orders and products is only for productCodes that are in both the orderdetails and products tables. If a product had yet to be ordered (and wasn't in the orderdetails table) then it would also not be in the result of the join.
#
# There are many other types of joins, displayed below. Of these, sqlite does not support outer joins, but it is good to be aware of as more powerful versions of sql such as PostgreSQL support these additional functions.
#
# <img src='images/venn.png' width="700">

# %% [markdown]
# For example, the statement
#
# `select * from products left join orderdetails; `
#
# would return all products, even those that hadn't been ordered.
# You can imagine that all products in inventory should have a description in the product table, but perhaps not every product is represented in the orderdetails table.

# %%
cur.execute("""select * from products
                        left join orderdetails
                        using(productCode);
                       """)
df = pd.DataFrame(cur.fetchall()) #Take results and create dataframe
df.columns = [i[0] for i in cur.description]
print(len(df))
print(len(df[df.orderNumber.isnull()]))
df[df.orderNumber.isnull()].head()
# Out:
# 2997
# 1
#      productCode        productName   productLine productScale  \
# 1122    S18_3233  1985 Toyota Supra  Classic Cars         1:18
#
#                  productVendor  \
# 1122  Highway 66 Mini Classics
#
#                                      productDescription quantityInStock  \
# 1122  This model features soft rubber tires, working...            7733
#
#      buyPrice    MSRP orderNumber quantityOrdered priceEach orderLineNumber
# 1122    57.01  107.57        None            None      None            None

# %% [markdown]
# As you can see, its rare, but there is one product that has yet to be ordered

# %% [markdown]
# ## Primary Versus Foreign Keys
#
# Another important consideration when performing joins is to think more about the key or column you are joining on. As you'll see in upcoming lessons, this can lead to interesting behavior if the join value is not unique in one or both of the tables. In all of the above examples, you joined two tables using the **primary key**. The primary key(s) of a table are those column(s) which uniquely identify a row. You'll also see this designated in our schema diagram with the asterisk (*).
# <img src='images/Database-Schema.png' width=550>

# %% [markdown]
# You can also join tables using **foreign keys** which are not the primary key for that particular table, but rather another table. For example, employeeNumber is the primary key for the employees table and corresponds to the salesRepEmployeeNumber of the customers table. In the customers table, salesRepEmployeeNumber is only a foreign key, and is unlikely to be a unique identifier, as it is likely that an employee serves multiple customers. As such, in the resulting view, employeeNumber would no longer be a unique field.

# %%
cur.execute("""select * from customers c
                        join employees e
                        on c.salesRepEmployeeNumber = e.employeeNumber
                        order by employeeNumber;
                       """)
df = pd.DataFrame(cur.fetchall()) #Take results and create dataframe
df.columns = [i[0] for i in cur.description]
df.head()
# Out:
#   customerNumber                  customerName contactLastName  \
# 0            124  Mini Gifts Distributors Ltd.          Nelson
# 1            129               Mini Wheels Co.          Murphy
# 2            161          Technics Stores Inc.       Hashimoto
# 3            321      Corporate Gift Ideas Co.           Brown
# 4            450     The Sharp Gifts Warehouse           Frick
#
#   contactFirstName       phone               addressLine1 addressLine2  \
# 0            Susan  4155551450            5677 Strong St.
# 1            Julie  6505555787  5557 North Pendale Street
# 2             Juri  6505556809          9408 Furth Circle
# 3            Julie  6505551386            7734 Strong St.
# 4              Sue  4085553659             3086 Ingle Ln.
#
#             city state postalCode    ...     salesRepEmployeeNumber  \
# 0     San Rafael    CA      97562    ...                       1165
# 1  San Francisco    CA      94217    ...                       1165
# 2     Burlingame    CA      94217    ...                       1165
# 3  San Francisco    CA      94217    ...                       1165
# 4       San Jose    CA      94217    ...                       1165
#
#   creditLimit employeeNumber  lastName firstName extension  \
# 0   210500.00           1165  Jennings    Leslie     x3291
# 1    64600.00           1165  Jennings    Leslie     x3291
# 2    84600.00           1165  Jennings    Leslie     x3291
# 3   105000.00           1165  Jennings    Leslie     x3291
# 4    77600.00           1165  Jennings    Leslie     x3291
#
#                             email officeCode reportsTo   jobTitle
# 0  ljennings@classicmodelcars.com          1      1143  Sales Rep
# 1  ljennings@classicmodelcars.com          1      1143  Sales Rep
# 2  ljennings@classicmodelcars.com          1      1143  Sales Rep
# 3  ljennings@classicmodelcars.com          1      1143  Sales Rep
# 4  ljennings@classicmodelcars.com          1      1143  Sales Rep
#
# [5 rows x 21 columns]

# %% [markdown]
# Notice that this also returned both columns: salesRepEmployeeNumber and employeeNumber.

# %% [markdown]
# ## Summary
#
# In this lesson you investigated joins including the on and using clause, aliasing table names, left joins and primary and foreign keys.
